# %%
import pandas as pd
import PyPDF2

# %%
pdf_file = open('CV_Neha.pdf', 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
num_of_pages = read_pdf.getNumPages()

page = read_pdf.getPage(0)
page_content = page.extractText()
print(page_content)
# Out:
# Neha Kale
#  Pune (Maha.), India
#  | (+91) 96230 66439 |
# nkale8013@gmail.com
#  | LinkedIn
#  | Github
# | Codechef
#  | GFG
#  Education
#     D.Y. Patil Institute of
# Engineeri
# ng, Management and Research
#  (Computer
#  Science)
#
#  Pune, Maharashtra
#  Bachelor of Engineering | CGPA: 9.68
#
#
#  Jul
# y™18 to Ju
# ne™
# 22   Kamalnayan Bajaj Higher Secondary School (Science)
#
#
#
# Pune, Maharashtra
#     Higher Secondary Education | Percentage: 86.77%
#
#   July
# ™16 to May
# ™18  Technical
#  Skills
#   Ł Programming
# Languages
# :
# C++
#  (Advance
# d),
# Python
#  (Beginner)
#  Ł Frameworks
# : Android
# -Java SDK, Scikit
# -learn
#  Ł Databases
# : SQL
# , Firebase
#  Ł Libraries
# : Pandas, NumPy, Scrapy, Beautiful Soup, Matplotlib, Seaborn
#  Ł Subjects
# :
# Data Structures and Algorithms, Operating Systems, Database
# Management
# Systems, Computer Organiz
# ation
# , Networking
#  Ł Version Control
# :
# Git
#   Projects
#    Daily Visit Report Application
#  Sep™20 to
# Nov
# ™20 Complete Business Handling Tool
# | Link
#  Ł It is a location
# -based android application to maintain the records and activities of the employees.
#  Ł The application supports functions such as
# Daily Check
# -ins,
# Expenses
#  and
# Bills
# ,
# To-do List
#  and also calculates
# Performance
#  of the
# employees to maintain a competitive work environment.
#  Ł Technologies:
# Android
# -Java, Google API, Firebase
#  Knowledge Management System
#  / Link
#  Jan™19 to
#  May™19
#     Smart India Hackathon 2020
# , Problem Statement by Airport Authority of India
#  (AAI)
#  Ł Our team of 6 members implemented solution on problem statem
# ent AK15 ‚
# Knowledge Management System using Blockchain
# ™. Ł This is a Web
# -Based Application that is used to upload and retrieve the Aerodrome Licensing Documents on Blockchain.
#  Ł I was associated with the UI
# -UX designing of the application
#  Ł Technologies:
# Ethereum, Truffle, MongoDB, IPFS, React JS, Node JS and Express
#  Shatakshi Classes
#   July™19 to
#  Aug™19
#
# Coaching Classes Website
#  | Link
#  Ł It is a
# n Educational Website which was built for a client in Pune.
#  Ł I designed its front
# -end, UI/UX as well as back
# -end using
# WordPress
#  and its plugins along with
# SEO
#  and
# SSL
# . Ł Technologies:
# WordPress
#   Professional
#  Experience
#    Data Analyst Intern, Authorva Pvt. Lt
# d.
#
# Mar™21
#  to
#  Apr™21
#  Ł Sales analysis and prediction of Global Superstore Dataset.
#  Ł Improved the efficiency of model w
# ith
# Accuracy score of 0.912
#  and
# Precision of 0.934
#  Ł Technologies Used: Pandas, NumPy, Matplotlib, Seaborn,
#  Scikit
# -Learn, Tensorflow
#   Bolt
# - IoT Student Partner Internship
#
# Jan™20
# to
#  Mar™20
#  Ł Popularized the concepts of
# IoT and Machine Learning
#  in our campus.
#  Ł Business Development of the Bolt IoT and ML online video training.
#   Achievements
#   Ł National Winners
#  - Smart India Hackathon 2020
#  Ł 3-star
# coder at
#  Codechef
#  Ł Runner Up
# - Barclays
# Tech
#  Innovation Challenge
# , provided sol
# utio
# n to problem ‚How to make Agricultur
# e Profit Venture
#  Business™
#  Ł School Topper Award
# , SMDYP English School, Score: 93.80%
#  Ł Won
# 2nd Prize
#  in
# VERTEXO 2020
# , an Ideathon organized by EDC Cell of DYPIEMR
#
# Extracurricular Activities
#    Chairperson
#  Œ ACM DYPIEMR Student Chapter
#  (2021
# -2022)
#
# Lead
# ing a team of 22 BODs and members
# , organizing many inter and intra college events,
# webinars and competitions.
#   RRRO (Rotary Rotaract Relationship Officer)
#  Œ Rotaract Club of DYPIEMR
#  (2020
# -2021)
#   Runner Up
# Œ Badminton (Intra College)
#   Reading, Badminton, Singing

# %%
import nltk
from nltk.corpus import stopwords

# removing punctuations

punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~ŁŒ'''

for ele in page_content:
    if ele in punc:
        page_content = page_content.replace(ele, "")

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(page_content)

# %%
filtered_resume = [w for w in word_tokens if not w.lower() in stop_words]

filtered_resume = []

for w in word_tokens:
    if w not in stop_words:
        filtered_resume.append(w)
 
print(word_tokens)
print(filtered_resume)
# Out:
# ['Neha', 'Kale', 'Pune', 'Maha', 'India', '|', '+91', '96230', '66439', '|', 'nkale8013gmailcom', '|', 'LinkedIn', '|', 'Github', '|', 'Codechef', '|', 'GFG', 'Education', 'DY', 'Patil', 'Institute', 'of', 'Engineeri', 'ng', 'Management', 'and', 'Research', 'Computer', 'Science', 'Pune', 'Maharashtra', 'Bachelor', 'of', 'Engineering', '|', 'CGPA', '968', 'Jul', 'y™18', 'to', 'Ju', 'ne™', '22', 'Kamalnayan', 'Bajaj', 'Higher', 'Secondary', 'School', 'Science', 'Pune', 'Maharashtra', 'Higher', 'Secondary', 'Education', '|', 'Percentage', '8677', 'July', '™16', 'to', 'May', '™18', 'Technical', 'Skills', 'Programming', 'Languages', 'C++', 'Advance', 'd', 'Python', 'Beginner', 'Frameworks', 'Android', 'Java', 'SDK', 'Scikit', 'learn', 'Databases', 'SQL', 'Firebase', 'Libraries', 'Pandas', 'NumPy', 'Scrapy', 'Beautiful', 'Soup', 'Matplotlib', 'Seaborn', 'Subjects', 'Data', 'Structures', 'and', 'Algorithms', 'Operating', 'Systems', 'Database', 'Management', 'Systems', 'Computer', 'Organiz', 'ation', 'Networking', 'Version', 'Control', 'Git', 'Projects', 'Daily', 'Visit', 'Report', 'Application', 'Sep™20', 'to', 'Nov', '™20', 'Complete', 'Business', 'Handling', 'Tool', '|', 'Link', 'It', 'is', 'a', 'location', 'based', 'android', 'application', 'to', 'maintain', 'the', 'records', 'and', 'activities', 'of', 'the', 'employees', 'The', 'application', 'supports', 'functions', 'such', 'as', 'Daily', 'Check', 'ins', 'Expenses', 'and', 'Bills', 'Todo', 'List', 'and', 'also', 'calculates', 'Performance', 'of', 'the', 'employees', 'to', 'maintain', 'a', 'competitive', 'work', 'environment', 'Technologies', 'Android', 'Java', 'Google', 'API', 'Firebase', 'Knowledge', 'Management', 'System', 'Link', 'Jan™19', 'to', 'May™19', 'Smart', 'India', 'Hackathon', '2020', 'Problem', 'Statement', 'by', 'Airport', 'Authority', 'of', 'India', 'AAI', 'Our', 'team', 'of', '6', 'members', 'implemented', 'solution', 'on', 'problem', 'statem', 'ent', 'AK15', '‚', 'Knowledge', 'Management', 'System', 'using', 'Blockchain', '™', 'This', 'is', 'a', 'Web', 'Based', 'Application', 'that', 'is', 'used', 'to', 'upload', 'and', 'retrieve', 'the', 'Aerodrome', 'Licensing', 'Documents', 'on', 'Blockchain', 'I', 'was', 'associated', 'with', 'the', 'UI', 'UX', 'designing', 'of', 'the', 'application', 'Technologies', 'Ethereum', 'Truffle', 'MongoDB', 'IPFS', 'React', 'JS', 'Node', 'JS', 'and', 'Express', 'Shatakshi', 'Classes', 'July™19', 'to', 'Aug™19', 'Coaching', 'Classes', 'Website', '|', 'Link', 'It', 'is', 'a', 'n', 'Educational', 'Website', 'which', 'was', 'built', 'for', 'a', 'client', 'in', 'Pune', 'I', 'designed', 'its', 'front', 'end', 'UIUX', 'as', 'well', 'as', 'back', 'end', 'using', 'WordPress', 'and', 'its', 'plugins', 'along', 'with', 'SEO', 'and', 'SSL', 'Technologies', 'WordPress', 'Professional', 'Experience', 'Data', 'Analyst', 'Intern', 'Authorva', 'Pvt', 'Lt', 'd', 'Mar™21', 'to', 'Apr™21', 'Sales', 'analysis', 'and', 'prediction', 'of', 'Global', 'Superstore', 'Dataset', 'Improved', 'the', 'efficiency', 'of', 'model', 'w', 'ith', 'Accuracy', 'score', 'of', '0912', 'and', 'Precision', 'of', '0934', 'Technologies', 'Used', 'Pandas', 'NumPy', 'Matplotlib', 'Seaborn', 'Scikit', 'Learn', 'Tensorflow', 'Bolt', 'IoT', 'Student', 'Partner', 'Internship', 'Jan™20', 'to', 'Mar™20', 'Popularized', 'the', 'concepts', 'of', 'IoT', 'and', 'Machine', 'Learning', 'in', 'our', 'campus', 'Business', 'Development', 'of', 'the', 'Bolt', 'IoT', 'and', 'ML', 'online', 'video', 'training', 'Achievements', 'National', 'Winners', 'Smart', 'India', 'Hackathon', '2020', '3star', 'coder', 'at', 'Codechef', 'Runner', 'Up', 'Barclays', 'Tech', 'Innovation', 'Challenge', 'provided', 'sol', 'utio', 'n', 'to', 'problem', '‚How', 'to', 'make', 'Agricultur', 'e', 'Profit', 'Venture', 'Business™', 'School', 'Topper', 'Award', 'SMDYP', 'English', 'School', 'Score', '9380', 'Won', '2nd', 'Prize', 'in', 'VERTEXO', '2020', 'an', 'Ideathon', 'organized', 'by', 'EDC', 'Cell', 'of', 'DYPIEMR', ...
# ['Neha', 'Kale', 'Pune', 'Maha', 'India', '|', '+91', '96230', '66439', '|', 'nkale8013gmailcom', '|', 'LinkedIn', '|', 'Github', '|', 'Codechef', '|', 'GFG', 'Education', 'DY', 'Patil', 'Institute', 'Engineeri', 'ng', 'Management', 'Research', 'Computer', 'Science', 'Pune', 'Maharashtra', 'Bachelor', 'Engineering', '|', 'CGPA', '968', 'Jul', 'y™18', 'Ju', 'ne™', '22', 'Kamalnayan', 'Bajaj', 'Higher', 'Secondary', 'School', 'Science', 'Pune', 'Maharashtra', 'Higher', 'Secondary', 'Education', '|', 'Percentage', '8677', 'July', '™16', 'May', '™18', 'Technical', 'Skills', 'Programming', 'Languages', 'C++', 'Advance', 'Python', 'Beginner', 'Frameworks', 'Android', 'Java', 'SDK', 'Scikit', 'learn', 'Databases', 'SQL', 'Firebase', 'Libraries', 'Pandas', 'NumPy', 'Scrapy', 'Beautiful', 'Soup', 'Matplotlib', 'Seaborn', 'Subjects', 'Data', 'Structures', 'Algorithms', 'Operating', 'Systems', 'Database', 'Management', 'Systems', 'Computer', 'Organiz', 'ation', 'Networking', 'Version', 'Control', 'Git', 'Projects', 'Daily', 'Visit', 'Report', 'Application', 'Sep™20', 'Nov', '™20', 'Complete', 'Business', 'Handling', 'Tool', '|', 'Link', 'It', 'location', 'based', 'android', 'application', 'maintain', 'records', 'activities', 'employees', 'The', 'application', 'supports', 'functions', 'Daily', 'Check', 'ins', 'Expenses', 'Bills', 'Todo', 'List', 'also', 'calculates', 'Performance', 'employees', 'maintain', 'competitive', 'work', 'environment', 'Technologies', 'Android', 'Java', 'Google', 'API', 'Firebase', 'Knowledge', 'Management', 'System', 'Link', 'Jan™19', 'May™19', 'Smart', 'India', 'Hackathon', '2020', 'Problem', 'Statement', 'Airport', 'Authority', 'India', 'AAI', 'Our', 'team', '6', 'members', 'implemented', 'solution', 'problem', 'statem', 'ent', 'AK15', '‚', 'Knowledge', 'Management', 'System', 'using', 'Blockchain', '™', 'This', 'Web', 'Based', 'Application', 'used', 'upload', 'retrieve', 'Aerodrome', 'Licensing', 'Documents', 'Blockchain', 'I', 'associated', 'UI', 'UX', 'designing', 'application', 'Technologies', 'Ethereum', 'Truffle', 'MongoDB', 'IPFS', 'React', 'JS', 'Node', 'JS', 'Express', 'Shatakshi', 'Classes', 'July™19', 'Aug™19', 'Coaching', 'Classes', 'Website', '|', 'Link', 'It', 'n', 'Educational', 'Website', 'built', 'client', 'Pune', 'I', 'designed', 'front', 'end', 'UIUX', 'well', 'back', 'end', 'using', 'WordPress', 'plugins', 'along', 'SEO', 'SSL', 'Technologies', 'WordPress', 'Professional', 'Experience', 'Data', 'Analyst', 'Intern', 'Authorva', 'Pvt', 'Lt', 'Mar™21', 'Apr™21', 'Sales', 'analysis', 'prediction', 'Global', 'Superstore', 'Dataset', 'Improved', 'efficiency', 'model', 'w', 'ith', 'Accuracy', 'score', '0912', 'Precision', '0934', 'Technologies', 'Used', 'Pandas', 'NumPy', 'Matplotlib', 'Seaborn', 'Scikit', 'Learn', 'Tensorflow', 'Bolt', 'IoT', 'Student', 'Partner', 'Internship', 'Jan™20', 'Mar™20', 'Popularized', 'concepts', 'IoT', 'Machine', 'Learning', 'campus', 'Business', 'Development', 'Bolt', 'IoT', 'ML', 'online', 'video', 'training', 'Achievements', 'National', 'Winners', 'Smart', 'India', 'Hackathon', '2020', '3star', 'coder', 'Codechef', 'Runner', 'Up', 'Barclays', 'Tech', 'Innovation', 'Challenge', 'provided', 'sol', 'utio', 'n', 'problem', '‚How', 'make', 'Agricultur', 'e', 'Profit', 'Venture', 'Business™', 'School', 'Topper', 'Award', 'SMDYP', 'English', 'School', 'Score', '9380', 'Won', '2nd', 'Prize', 'VERTEXO', '2020', 'Ideathon', 'organized', 'EDC', 'Cell', 'DYPIEMR', 'Extracurricular', 'Activities', 'Chairperson', 'ACM', 'DYPIEMR', 'Student', 'Chapter', '2021', '2022', 'Lead', 'ing', 'team', '22', 'BODs', 'members', 'organizing', 'many', 'inter', 'intra', 'college', 'events', 'webinars', 'competitions', 'RRRO', 'Rotary', 'Rotaract', 'Relationship', 'Officer', 'Rotaract', 'Club', 'DYPIEMR', '2020', '2021', 'Runner', 'Up', 'Badminton', 'Intra', 'College', 'Reading', 'Badminton', 'Singing']

# %% [markdown]
# # Spell Check

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled = spell.unknown(word_tokens)

for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))

    # Get a list of `likely` options
#     print(spell.candidates(word))
# Out:
# walkathon
# i
# linkedln
# i
# how
# business
# codechef
# new
# six
# ed
# kamalnayan
# sody
# ™18
# seaborne
# up
# can
# ™16
# gig
# scrap
# aii
# put
# raro
# sep™20
# author
# jan™19
# i
# retract
# plains
# is
# state
# i
# am
# shatakshi
# sol
# jan™20
# engineer
# github
# seminars
# it
# ethereal
# mar™21
# aug™19
# tensorflow
# no
# i
# ideation
# suk
# matplotlib
# nkale8013gmailcom
# apr™21
# bumpy
# mar™20
# tio
# gpa
# organic
# agriculture
# sol
# maharashtrian
# and
# my
# spirit
# aka
# dypiemr
# may™19
# baja
# ™20
# july™19
# mongols
# wordless
# vertex
# ifs
# y™18
# star

# %% [markdown]
# # Grammar Check

# %%
# import language_tool_python
# import grammar_check

# tool = language_tool_python.LanguageTool('en-US')
 
# # get the matches
# matches = tool.check(page_content)
# matches

# my_mistakes = []
# my_corrections = []
# start_positions = []
# end_positions = []
 
# for rules in matches:
#     if len(rules.replacements)>0:
#         start_positions.append(rules.offset)
#         end_positions.append(rules.errorLength+rules.offset)
#         my_mistakes.append(text[rules.offset:rules.errorLength+rules.offset])
#         my_corrections.append(rules.replacements[0])
     
 
     
# my_new_text = list(page_content)
 
 
# for m in range(len(start_positions)):
#     for i in range(len(text)):
#         my_new_text[start_positions[m]] = my_corrections[m]
#         if (i>start_positions[m] and i<end_positions[m]):
#             my_new_text[i]=""
     
# my_new_text = "".join(my_new_text)
# my_new_text

# %%
import language_check


# Mention the language keyword
tool = language_check.LanguageTool('en-US')
i = 0

# Path of file which needs to be checked
with open(r'transcript1.txt', 'r') as fin:
			
	for line in fin:
		matches = tool.check(line)
		i = i + len(matches)	
		pass

# prints total mistakes which are found
# from the document
print("No. of mistakes found in document is ", i)
print()
	
# prints mistake one by one
for mistake in matches:
	print(mistake)
	print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23696/2480839652.py in <module>
# ----> 1 import language_check
#       2
#       3
#       4 # Mention the language keyword
#       5 tool = language_check.LanguageTool('en-US')
#
# ModuleNotFoundError: No module named 'language_check'
